# %% [markdown]
# ### Importing necessary libs

# %%
from sklearn.ensemble import ExtraTreesRegressor
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# #### Loading dataset

# %%
data=pd.read_csv("AQI_Data.csv")

# %%
data.isnull().sum()
# Out:
# T         0
# TM        0
# Tm        0
# SLP       0
# H         0
# VV        0
# V         0
# VM        0
# PM 2.5    1
# dtype: int64

# %% [markdown]
# #### Dropping the one & only missing value

# %%
data=data.dropna()

# %%
data.isnull().sum()
# Out:
# T         0
# TM        0
# Tm        0
# SLP       0
# H         0
# VV        0
# V         0
# VM        0
# PM 2.5    0
# dtype: int64

# %% [markdown]
# #### Separating data & features

# %%
X=data.iloc[:,:-1] ## independent features
Y=data.iloc[:,-1]  ## dependent features

# %%
X.isnull().sum()
# Out:
# T      0
# TM     0
# Tm     0
# SLP    0
# H      0
# VV     0
# V      0
# VM     0
# dtype: int64

# %%
Y.isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Conducting feature importance

# %%
model=ExtraTreesRegressor()

# %%
model.fit(X,Y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [0.18807346 0.10532941 0.17841102 0.15476225 0.08759398 0.19064349
#  0.05408535 0.04110103]

# %%
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(8).plot(kind='barh')
plt.show()

# %%
sns.distplot(Y)
# Out:
# C:\Users\kanch\AppData\Local\Temp\ipykernel_8888\3269117342.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Y)
# <Axes: xlabel='PM 2.5', ylabel='Density'>

# %% [markdown]
# ### Splitting the dataset

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=5)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
import xgboost as xgb

# %%
regressor=xgb.XGBRegressor()
regressor.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
print("Coefficient of determination R^2 <-- on train set: {}".format(regressor.score(X_train, y_train)))
# Out:
# Coefficient of determination R^2 <-- on train set: 0.9998008668280981

# %%
print("Coefficient of determination R^2 <-- on train set: {}".format(regressor.score(X_test, y_test)))
# Out:
# Coefficient of determination R^2 <-- on train set: 0.7789672842036623

# %% [markdown]
# ### Performing K fold CV

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(regressor,X,Y,cv=5)

# %%
score.mean()
# Out:
# 0.744970110899368

# %%
prediction=regressor.predict(X_test)

# %%
sns.distplot(y_test-prediction)
# Out:
# C:\Users\kanch\AppData\Local\Temp\ipykernel_8888\1520944062.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test-prediction)
# <Axes: xlabel='PM 2.5', ylabel='Density'>

# %% [markdown]
# ### Hyperparameter Tuning with RandomizedSearchCV

# %%
xgb.XGBRegressor()
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
import numpy as np
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
print(n_estimators)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]

# %%
#Randomized Search CV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
# Various learning rate parameters
learning_rate = ['0.05','0.1', '0.2','0.3','0.5','0.6']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# max_depth.append(None)
#Subssample parameter values
subsample=[0.7,0.6,0.8]
# Minimum child weight parameters
min_child_weight=[3,4,5,6,7]

# %%
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'learning_rate': learning_rate,
               'max_depth': max_depth,
               'subsample': subsample,
               'min_child_weight': min_child_weight}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'learning_rate': ['0.05', '0.1', '0.2', '0.3', '0.5', '0.6'], 'max_depth': [5, 10, 15, 20, 25, 30], 'subsample': [0.7, 0.6, 0.8], 'min_child_weight': [3, 4, 5, 6, 7]}

# %%
# Use the random grid to search for best hyperparameters
# First create the base model to tune
regressor=xgb.XGBRegressor()

# %%
xg_random = RandomizedSearchCV(estimator = regressor, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 500, cv = 5, verbose=2, random_state=42, n_jobs = 1)

# %%
xg_random.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 500 candidates, totalling 2500 fits
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=6, n_estimators=1100, subsample=0.7; total time=   0.8s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=6, n_estimators=1100, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=6, n_estimators=1100, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=6, n_estimators=1100, subsample=0.7; total time=   1.1s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=6, n_estimators=1100, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=6, n_estimators=600, subsample=0.7; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=6, n_estimators=600, subsample=0.7; total time=   0.8s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=6, n_estimators=600, subsample=0.7; total time=   0.8s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=6, n_estimators=600, subsample=0.7; total time=   1.1s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=6, n_estimators=600, subsample=0.7; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=7, n_estimators=300, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=7, n_estimators=300, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=7, n_estimators=300, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=7, n_estimators=300, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=7, n_estimators=300, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=7, n_estimators=1000, subsample=0.7; total time=   1.2s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=7, n_estimators=1000, subsample=0.7; total time=   1.0s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=7, n_estimators=1000, subsample=0.7; total time=   1.2s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=7, n_estimators=1000, subsample=0.7; total time=   1.0s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=7, n_estimators=1000, subsample=0.7; total time=   1.0s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=3, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=3, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=3, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=3, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=3, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=6, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=6, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=6, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=6, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=6, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.2, max_depth=25, min_child_weight=7, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.2, max_depth=25, min_child_weight=7, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.2, max_depth=25, min_child_weight=7, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.2, max_depth=25, min_child_weight=7, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.2, max_depth=25, min_child_weight=7, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=900, subsample=0.6; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=900, subsample=0.6; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=900, subsample=0.6; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=900, subsample=0.6; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=900, subsample=0.6; total time=   1.0s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=6, n_estimators=500, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=6, n_estimators=500, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=6, n_estimators=500, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=6, n_estimators=500, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=6, n_estimators=500, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=1000, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=1000, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=1000, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=1000, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=1000, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=5, n_estimators=800, subsample=0.7; total time=   1.4s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=5, n_estimators=800, subsample=0.7; total time=   1.1s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=5, n_estimators=800, subsample=0.7; total time=   1.1s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=5, n_estimators=800, subsample=0.7; total time=   1.4s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=5, n_estimators=800, subsample=0.7; total time=   1.3s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=7, n_estimators=200, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=7, n_estimators=200, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=7, n_estimators=200, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=7, n_estimators=200, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=7, n_estimators=200, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=3, n_estimators=800, subsample=0.7; total time=   1.7s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=3, n_estimators=800, subsample=0.7; total time=   1.5s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=3, n_estimators=800, subsample=0.7; total time=   1.7s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=3, n_estimators=800, subsample=0.7; total time=   1.9s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=3, n_estimators=800, subsample=0.7; total time=   1.8s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=4, n_estimators=800, subsample=0.7; total time=   2.1s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=4, n_estimators=800, subsample=0.7; total time=   2.0s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=4, n_estimators=800, subsample=0.7; total time=   1.9s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=4, n_estimators=800, subsample=0.7; total time=   2.1s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=4, n_estimators=800, subsample=0.7; total time=   2.3s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=7, n_estimators=1100, subsample=0.7; total time=   1.1s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=7, n_estimators=1100, subsample=0.7; total time=   0.9s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=7, n_estimators=1100, subsample=0.7; total time=   0.9s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=7, n_estimators=1100, subsample=0.7; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=7, n_estimators=1100, subsample=0.7; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=25, min_child_weight=5, n_estimators=800, subsample=0.6; total time=   1.4s
# [CV] END learning_rate=0.3, max_depth=25, min_child_weight=5, n_estimators=800, subsample=0.6; total time=   1.1s
# [CV] END learning_rate=0.3, max_depth=25, min_child_weight=5, n_estimators=800, subsample=0.6; total time=   1.0s
# [CV] END learning_rate=0.3, max_depth=25, min_child_weight=5, n_estimators=800, subsample=0.6; total time=   1.6s
# [CV] END learning_rate=0.3, max_depth=25, min_child_weight=5, n_estimators=800, subsample=0.6; total time=   1.7s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=600, subsample=0.6; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=600, subsample=0.6; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=600, subsample=0.6; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=600, subsample=0.6; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=600, subsample=0.6; total time=   0.8s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=4, n_estimators=500, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=4, n_estimators=500, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=4, n_estimators=500, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=4, n_estimators=500, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=4, n_estimators=500, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=3, n_estimators=500, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=3, n_estimators=500, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=3, n_estimators=500, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=3, n_estimators=500, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=3, n_estimators=500, subsample=0.8; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=6, n_estimators=300, subsample=0.6; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=6, n_estimators=300, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=6, n_estimators=300, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=6, n_estimators=300, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=6, n_estimators=300, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=7, n_estimators=700, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=7, n_estimators=700, subsample=0.8; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=7, n_estimators=700, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=7, n_estimators=700, subsample=0.8; total time=   0.9s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=7, n_estimators=700, subsample=0.8; total time=   1.0s
# [CV] END learning_rate=0.6, max_depth=20, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.6, max_depth=20, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.6, max_depth=20, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.6, max_depth=20, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.6, max_depth=20, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   1.0s
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   1.1s
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   1.0s
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   1.2s
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=3, n_estimators=800, subsample=0.6; total time=   2.1s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=3, n_estimators=800, subsample=0.6; total time=   1.9s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=3, n_estimators=800, subsample=0.6; total time=   1.8s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=3, n_estimators=800, subsample=0.6; total time=   1.8s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=3, n_estimators=800, subsample=0.6; total time=   2.6s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=4, n_estimators=400, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=4, n_estimators=400, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=4, n_estimators=400, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=4, n_estimators=400, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=4, n_estimators=400, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=4, n_estimators=300, subsample=0.8; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=4, n_estimators=300, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=4, n_estimators=300, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=4, n_estimators=300, subsample=0.8; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=4, n_estimators=300, subsample=0.8; total time=   0.8s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=7, n_estimators=300, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=7, n_estimators=300, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=7, n_estimators=300, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=7, n_estimators=300, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=7, n_estimators=300, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=3, n_estimators=1200, subsample=0.6; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=3, n_estimators=1200, subsample=0.6; total time=   1.0s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=3, n_estimators=1200, subsample=0.6; total time=   1.2s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=3, n_estimators=1200, subsample=0.6; total time=   1.2s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=3, n_estimators=1200, subsample=0.6; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=1200, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=1200, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=1200, subsample=0.7; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=1200, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=1200, subsample=0.7; total time=   0.9s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=6, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=6, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=6, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=6, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=6, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=7, n_estimators=800, subsample=0.7; total time=   0.9s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=7, n_estimators=800, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=7, n_estimators=800, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=7, n_estimators=800, subsample=0.7; total time=   1.1s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=7, n_estimators=800, subsample=0.7; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=200, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=200, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=200, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=200, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=200, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=7, n_estimators=200, subsample=0.8; total time=   0.8s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=7, n_estimators=200, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=7, n_estimators=200, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=7, n_estimators=200, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=7, n_estimators=200, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=6, n_estimators=1200, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=6, n_estimators=1200, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=6, n_estimators=1200, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=6, n_estimators=1200, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=6, n_estimators=1200, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=6, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=6, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=6, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=6, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=6, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=1000, subsample=0.6; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=1000, subsample=0.6; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=1000, subsample=0.6; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=1000, subsample=0.6; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=1000, subsample=0.6; total time=   1.5s
# [CV] END learning_rate=0.6, max_depth=5, min_child_weight=7, n_estimators=400, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.6, max_depth=5, min_child_weight=7, n_estimators=400, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.6, max_depth=5, min_child_weight=7, n_estimators=400, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.6, max_depth=5, min_child_weight=7, n_estimators=400, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.6, max_depth=5, min_child_weight=7, n_estimators=400, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=7, n_estimators=900, subsample=0.8; total time=   1.0s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=7, n_estimators=900, subsample=0.8; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=7, n_estimators=900, subsample=0.8; total time=   1.0s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=7, n_estimators=900, subsample=0.8; total time=   1.2s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=7, n_estimators=900, subsample=0.8; total time=   1.0s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.6, max_depth=10, min_child_weight=7, n_estimators=900, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.6, max_depth=10, min_child_weight=7, n_estimators=900, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.6, max_depth=10, min_child_weight=7, n_estimators=900, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.6, max_depth=10, min_child_weight=7, n_estimators=900, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.6, max_depth=10, min_child_weight=7, n_estimators=900, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=7, n_estimators=500, subsample=0.8; total time=   1.0s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=7, n_estimators=500, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=7, n_estimators=500, subsample=0.8; total time=   0.8s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=7, n_estimators=500, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=7, n_estimators=500, subsample=0.8; total time=   0.8s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=7, n_estimators=1000, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=7, n_estimators=1000, subsample=0.8; total time=   0.8s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=7, n_estimators=1000, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=7, n_estimators=1000, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=7, n_estimators=1000, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=1100, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=1100, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=1100, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=1100, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=1100, subsample=0.6; total time=   0.8s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   3.0s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   3.1s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   2.7s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   2.9s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   3.0s
# [CV] END learning_rate=0.2, max_depth=30, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   1.8s
# [CV] END learning_rate=0.2, max_depth=30, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   1.3s
# [CV] END learning_rate=0.2, max_depth=30, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   1.5s
# [CV] END learning_rate=0.2, max_depth=30, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   2.1s
# [CV] END learning_rate=0.2, max_depth=30, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   2.2s
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=5, n_estimators=1200, subsample=0.8; total time=   0.8s
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=5, n_estimators=1200, subsample=0.8; total time=   0.8s
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=5, n_estimators=1200, subsample=0.8; total time=   0.8s
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=5, n_estimators=1200, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=5, n_estimators=1200, subsample=0.8; total time=   0.8s
# [CV] END learning_rate=0.6, max_depth=10, min_child_weight=4, n_estimators=900, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.6, max_depth=10, min_child_weight=4, n_estimators=900, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.6, max_depth=10, min_child_weight=4, n_estimators=900, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.6, max_depth=10, min_child_weight=4, n_estimators=900, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.6, max_depth=10, min_child_weight=4, n_estimators=900, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=6, n_estimators=1100, subsample=0.8; total time=   2.3s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=6, n_estimators=1100, subsample=0.8; total time=   2.1s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=6, n_estimators=1100, subsample=0.8; total time=   1.9s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=6, n_estimators=1100, subsample=0.8; total time=   2.3s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=6, n_estimators=1100, subsample=0.8; total time=   2.0s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=7, n_estimators=800, subsample=0.6; total time=   0.8s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=7, n_estimators=800, subsample=0.6; total time=   0.8s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=7, n_estimators=800, subsample=0.6; total time=   0.9s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=7, n_estimators=800, subsample=0.6; total time=   0.9s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=7, n_estimators=800, subsample=0.6; total time=   0.9s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=6, n_estimators=1200, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=6, n_estimators=1200, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=6, n_estimators=1200, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=6, n_estimators=1200, subsample=0.8; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=6, n_estimators=1200, subsample=0.8; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=900, subsample=0.7; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=900, subsample=0.7; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=900, subsample=0.7; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=900, subsample=0.7; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=900, subsample=0.7; total time=   1.4s
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=6, n_estimators=900, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=6, n_estimators=900, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=6, n_estimators=900, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=6, n_estimators=900, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=6, n_estimators=900, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=15, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=15, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=15, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=15, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=15, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   0.8s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.5, max_depth=15, min_child_weight=6, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=15, min_child_weight=6, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=15, min_child_weight=6, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=15, min_child_weight=6, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=15, min_child_weight=6, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=6, n_estimators=400, subsample=0.7; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=6, n_estimators=400, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=6, n_estimators=400, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=6, n_estimators=400, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=6, n_estimators=400, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=7, n_estimators=800, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=7, n_estimators=800, subsample=0.7; total time=   0.8s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=7, n_estimators=800, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=7, n_estimators=800, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=7, n_estimators=800, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=6, n_estimators=300, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=6, n_estimators=300, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=6, n_estimators=300, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=6, n_estimators=300, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=6, n_estimators=300, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=5, n_estimators=300, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=5, n_estimators=300, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=5, n_estimators=300, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=5, n_estimators=300, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=5, n_estimators=300, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.2, max_depth=25, min_child_weight=4, n_estimators=600, subsample=0.6; total time=   1.3s
# [CV] END learning_rate=0.2, max_depth=25, min_child_weight=4, n_estimators=600, subsample=0.6; total time=   1.1s
# [CV] END learning_rate=0.2, max_depth=25, min_child_weight=4, n_estimators=600, subsample=0.6; total time=   1.1s
# [CV] END learning_rate=0.2, max_depth=25, min_child_weight=4, n_estimators=600, subsample=0.6; total time=   1.3s
# [CV] END learning_rate=0.2, max_depth=25, min_child_weight=4, n_estimators=600, subsample=0.6; total time=   1.5s
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=3, n_estimators=200, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=3, n_estimators=200, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=3, n_estimators=200, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=3, n_estimators=200, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=3, n_estimators=200, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=3, n_estimators=800, subsample=0.7; total time=   2.3s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=3, n_estimators=800, subsample=0.7; total time=   2.1s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=3, n_estimators=800, subsample=0.7; total time=   2.2s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=3, n_estimators=800, subsample=0.7; total time=   2.1s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=3, n_estimators=800, subsample=0.7; total time=   1.9s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=4, n_estimators=800, subsample=0.8; total time=   1.3s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=4, n_estimators=800, subsample=0.8; total time=   1.0s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=4, n_estimators=800, subsample=0.8; total time=   1.1s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=4, n_estimators=800, subsample=0.8; total time=   1.1s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=4, n_estimators=800, subsample=0.8; total time=   1.0s
# [CV] END learning_rate=0.6, max_depth=5, min_child_weight=4, n_estimators=600, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.6, max_depth=5, min_child_weight=4, n_estimators=600, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.6, max_depth=5, min_child_weight=4, n_estimators=600, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.6, max_depth=5, min_child_weight=4, n_estimators=600, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.6, max_depth=5, min_child_weight=4, n_estimators=600, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=5, n_estimators=900, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=5, n_estimators=900, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=5, n_estimators=900, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=5, n_estimators=900, subsample=0.6; total time=   0.9s
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=5, n_estimators=900, subsample=0.6; total time=   0.9s
# [CV] END learning_rate=0.5, max_depth=10, min_child_weight=5, n_estimators=1100, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.5, max_depth=10, min_child_weight=5, n_estimators=1100, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=10, min_child_weight=5, n_estimators=1100, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.5, max_depth=10, min_child_weight=5, n_estimators=1100, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=10, min_child_weight=5, n_estimators=1100, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=900, subsample=0.8; total time=   3.4s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=900, subsample=0.8; total time=   3.0s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=900, subsample=0.8; total time=   2.5s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=900, subsample=0.8; total time=   2.6s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=900, subsample=0.8; total time=   2.8s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=7, n_estimators=500, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=7, n_estimators=500, subsample=0.8; total time=   0.9s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=7, n_estimators=500, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=7, n_estimators=500, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=7, n_estimators=500, subsample=0.8; total time=   0.8s
# [CV] END learning_rate=0.2, max_depth=15, min_child_weight=6, n_estimators=500, subsample=0.7; total time=   0.8s
# [CV] END learning_rate=0.2, max_depth=15, min_child_weight=6, n_estimators=500, subsample=0.7; total time=   0.8s
# [CV] END learning_rate=0.2, max_depth=15, min_child_weight=6, n_estimators=500, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.2, max_depth=15, min_child_weight=6, n_estimators=500, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.2, max_depth=15, min_child_weight=6, n_estimators=500, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=3, n_estimators=400, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=3, n_estimators=400, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=3, n_estimators=400, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=3, n_estimators=400, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=3, n_estimators=400, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=3, n_estimators=900, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=3, n_estimators=900, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=3, n_estimators=900, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=3, n_estimators=900, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=3, n_estimators=900, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=6, n_estimators=600, subsample=0.6; total time=   1.0s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=6, n_estimators=600, subsample=0.6; total time=   0.9s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=6, n_estimators=600, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=6, n_estimators=600, subsample=0.6; total time=   0.9s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=6, n_estimators=600, subsample=0.6; total time=   0.8s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=4, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=4, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=4, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=4, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=4, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=700, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=700, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=700, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=700, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=700, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=4, n_estimators=100, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=4, n_estimators=100, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=4, n_estimators=100, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=4, n_estimators=100, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=4, n_estimators=100, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=25, min_child_weight=4, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=25, min_child_weight=4, n_estimators=100, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=25, min_child_weight=4, n_estimators=100, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=25, min_child_weight=4, n_estimators=100, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=25, min_child_weight=4, n_estimators=100, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=900, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=900, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=900, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=900, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=900, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=5, n_estimators=800, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=5, n_estimators=800, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=5, n_estimators=800, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=5, n_estimators=800, subsample=0.6; total time=   0.9s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=5, n_estimators=800, subsample=0.6; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=4, n_estimators=400, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=4, n_estimators=400, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=4, n_estimators=400, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=4, n_estimators=400, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=4, n_estimators=400, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=5, n_estimators=400, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=5, n_estimators=400, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=5, n_estimators=400, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=5, n_estimators=400, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=5, n_estimators=400, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=6, n_estimators=300, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=6, n_estimators=300, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=6, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=6, n_estimators=300, subsample=0.6; total time=   0.2s
# ...
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=6, n_estimators=900, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=6, n_estimators=900, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=6, n_estimators=900, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=6, n_estimators=900, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.2, max_depth=30, min_child_weight=7, n_estimators=800, subsample=0.8; total time=   1.9s
# [CV] END learning_rate=0.2, max_depth=30, min_child_weight=7, n_estimators=800, subsample=0.8; total time=   1.4s
# [CV] END learning_rate=0.2, max_depth=30, min_child_weight=7, n_estimators=800, subsample=0.8; total time=   1.5s
# [CV] END learning_rate=0.2, max_depth=30, min_child_weight=7, n_estimators=800, subsample=0.8; total time=   2.0s
# [CV] END learning_rate=0.2, max_depth=30, min_child_weight=7, n_estimators=800, subsample=0.8; total time=   1.5s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=4, n_estimators=1100, subsample=0.7; total time=   1.0s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=4, n_estimators=1100, subsample=0.7; total time=   0.8s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=4, n_estimators=1100, subsample=0.7; total time=   0.8s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=4, n_estimators=1100, subsample=0.7; total time=   0.8s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=4, n_estimators=1100, subsample=0.7; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=300, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=300, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=300, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=300, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=300, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=7, n_estimators=1000, subsample=0.6; total time=   1.8s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=7, n_estimators=1000, subsample=0.6; total time=   1.8s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=7, n_estimators=1000, subsample=0.6; total time=   1.9s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=7, n_estimators=1000, subsample=0.6; total time=   1.9s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=7, n_estimators=1000, subsample=0.6; total time=   1.7s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=600, subsample=0.6; total time=   0.8s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=600, subsample=0.6; total time=   1.0s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=600, subsample=0.6; total time=   0.9s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=600, subsample=0.6; total time=   1.1s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=600, subsample=0.6; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=6, n_estimators=600, subsample=0.6; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=6, n_estimators=600, subsample=0.6; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=6, n_estimators=600, subsample=0.6; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=6, n_estimators=600, subsample=0.6; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=6, n_estimators=600, subsample=0.6; total time=   1.2s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=4, n_estimators=1000, subsample=0.6; total time=   1.3s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=4, n_estimators=1000, subsample=0.6; total time=   1.3s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=4, n_estimators=1000, subsample=0.6; total time=   1.3s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=4, n_estimators=1000, subsample=0.6; total time=   1.6s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=4, n_estimators=1000, subsample=0.6; total time=   2.1s
# [CV] END learning_rate=0.2, max_depth=30, min_child_weight=4, n_estimators=300, subsample=0.6; total time=   0.8s
# [CV] END learning_rate=0.2, max_depth=30, min_child_weight=4, n_estimators=300, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.2, max_depth=30, min_child_weight=4, n_estimators=300, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.2, max_depth=30, min_child_weight=4, n_estimators=300, subsample=0.6; total time=   0.9s
# [CV] END learning_rate=0.2, max_depth=30, min_child_weight=4, n_estimators=300, subsample=0.6; total time=   0.8s
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=6, n_estimators=600, subsample=0.6; total time=   0.8s
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=6, n_estimators=600, subsample=0.6; total time=   0.8s
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=6, n_estimators=600, subsample=0.6; total time=   1.1s
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=6, n_estimators=600, subsample=0.6; total time=   0.9s
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=6, n_estimators=600, subsample=0.6; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=7, n_estimators=900, subsample=0.6; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=7, n_estimators=900, subsample=0.6; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=7, n_estimators=900, subsample=0.6; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=7, n_estimators=900, subsample=0.6; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=7, n_estimators=900, subsample=0.6; total time=   1.8s
# [CV] END learning_rate=0.05, max_depth=25, min_child_weight=5, n_estimators=700, subsample=0.6; total time=   1.6s
# [CV] END learning_rate=0.05, max_depth=25, min_child_weight=5, n_estimators=700, subsample=0.6; total time=   1.5s
# [CV] END learning_rate=0.05, max_depth=25, min_child_weight=5, n_estimators=700, subsample=0.6; total time=   1.7s
# [CV] END learning_rate=0.05, max_depth=25, min_child_weight=5, n_estimators=700, subsample=0.6; total time=   1.7s
# [CV] END learning_rate=0.05, max_depth=25, min_child_weight=5, n_estimators=700, subsample=0.6; total time=   1.5s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=7, n_estimators=900, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=7, n_estimators=900, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=7, n_estimators=900, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=7, n_estimators=900, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=7, n_estimators=900, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=5, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=5, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=5, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=5, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=5, n_estimators=100, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=6, n_estimators=900, subsample=0.7; total time=   1.5s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=6, n_estimators=900, subsample=0.7; total time=   1.0s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=6, n_estimators=900, subsample=0.7; total time=   1.3s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=6, n_estimators=900, subsample=0.7; total time=   1.5s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=6, n_estimators=900, subsample=0.7; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=6, n_estimators=600, subsample=0.7; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=6, n_estimators=600, subsample=0.7; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=6, n_estimators=600, subsample=0.7; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=6, n_estimators=600, subsample=0.7; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=6, n_estimators=600, subsample=0.7; total time=   1.4s
# [CV] END learning_rate=0.3, max_depth=25, min_child_weight=4, n_estimators=1100, subsample=0.8; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=25, min_child_weight=4, n_estimators=1100, subsample=0.8; total time=   1.0s
# [CV] END learning_rate=0.3, max_depth=25, min_child_weight=4, n_estimators=1100, subsample=0.8; total time=   1.0s
# [CV] END learning_rate=0.3, max_depth=25, min_child_weight=4, n_estimators=1100, subsample=0.8; total time=   1.1s
# [CV] END learning_rate=0.3, max_depth=25, min_child_weight=4, n_estimators=1100, subsample=0.8; total time=   1.1s
# [CV] END learning_rate=0.2, max_depth=5, min_child_weight=4, n_estimators=1000, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.2, max_depth=5, min_child_weight=4, n_estimators=1000, subsample=0.8; total time=   1.0s
# [CV] END learning_rate=0.2, max_depth=5, min_child_weight=4, n_estimators=1000, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.2, max_depth=5, min_child_weight=4, n_estimators=1000, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.2, max_depth=5, min_child_weight=4, n_estimators=1000, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=6, n_estimators=900, subsample=0.7; total time=   2.4s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=6, n_estimators=900, subsample=0.7; total time=   2.3s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=6, n_estimators=900, subsample=0.7; total time=   2.6s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=6, n_estimators=900, subsample=0.7; total time=   4.1s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=6, n_estimators=900, subsample=0.7; total time=   5.0s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=5, n_estimators=300, subsample=0.6; total time=   1.1s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=5, n_estimators=300, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=5, n_estimators=300, subsample=0.6; total time=   0.9s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=5, n_estimators=300, subsample=0.6; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=5, n_estimators=300, subsample=0.6; total time=   0.9s
# [CV] END learning_rate=0.2, max_depth=15, min_child_weight=6, n_estimators=900, subsample=0.6; total time=   1.9s
# [CV] END learning_rate=0.2, max_depth=15, min_child_weight=6, n_estimators=900, subsample=0.6; total time=   2.1s
# [CV] END learning_rate=0.2, max_depth=15, min_child_weight=6, n_estimators=900, subsample=0.6; total time=   2.4s
# [CV] END learning_rate=0.2, max_depth=15, min_child_weight=6, n_estimators=900, subsample=0.6; total time=   3.0s
# [CV] END learning_rate=0.2, max_depth=15, min_child_weight=6, n_estimators=900, subsample=0.6; total time=   2.5s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=700, subsample=0.6; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=700, subsample=0.6; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=700, subsample=0.6; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=700, subsample=0.6; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=700, subsample=0.6; total time=   1.0s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=7, n_estimators=400, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=7, n_estimators=400, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=7, n_estimators=400, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=7, n_estimators=400, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=7, n_estimators=400, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=25, min_child_weight=3, n_estimators=1000, subsample=0.7; total time=   3.1s
# [CV] END learning_rate=0.05, max_depth=25, min_child_weight=3, n_estimators=1000, subsample=0.7; total time=   3.0s
# [CV] END learning_rate=0.05, max_depth=25, min_child_weight=3, n_estimators=1000, subsample=0.7; total time=   3.0s
# [CV] END learning_rate=0.05, max_depth=25, min_child_weight=3, n_estimators=1000, subsample=0.7; total time=   3.3s
# [CV] END learning_rate=0.05, max_depth=25, min_child_weight=3, n_estimators=1000, subsample=0.7; total time=   3.0s
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=7, n_estimators=1200, subsample=0.8; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=7, n_estimators=1200, subsample=0.8; total time=   1.1s
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=7, n_estimators=1200, subsample=0.8; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=7, n_estimators=1200, subsample=0.8; total time=   1.3s
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=7, n_estimators=1200, subsample=0.8; total time=   1.6s
# RandomizedSearchCV(cv=5,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, device=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, feature_types=None,
#                                           gamma=None, grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraints=None,
#                                           learning_rate=...
#                                           num_parallel_tree=None,
#                                           random_state=None, ...),
#                    n_iter=500, n_jobs=1,
#                    param_distributions={'learning_rate': ['0.05', '0.1', '0.2',
#                                                           '0.3', '0.5', '0.6'],
#                                         'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'min_child_weight': [3, 4, 5, 6, 7],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100,
#                                                          1200],
#                                         'subsample': [0.7, 0.6, 0.8]},
#                    random_state=42, scoring='neg_mean_squared_error',
#                    verbose=2)

# %% [markdown]
# #### best params obtained

# %%
xg_random.best_params_
# Out:
# {'subsample': 0.6,
#  'n_estimators': 800,
#  'min_child_weight': 5,
#  'max_depth': 20,
#  'learning_rate': '0.2'}

# %%
xg_random.best_score_
# Out:
# -1599.7927639575032

# %%
xg_random.best_score_
# Out:
# -1599.7927639575032

# %%
predictions=xg_random.predict(X_test)

# %%
sns.distplot(y_test-predictions)
# Out:
# C:\Users\kanch\AppData\Local\Temp\ipykernel_8888\2131792714.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test-predictions)
# <Axes: xlabel='PM 2.5', ylabel='Density'>

# %%
plt.scatter(y_test,predictions)

# %% [markdown]
# ### Evaluation

# %% [markdown]
# #### metrics with hyperparameter tuning

# %%
# with hyperparameter tuning
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 18.571662086713673
# MSE: 1388.8581213327993
# RMSE: 37.267386832628866

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 18.571662086713673
# MSE: 1388.8581213327993
# RMSE: 37.267386832628866

# %% [markdown]
# #### metrics without hyperparamter tuning

# %%
# w/o hyperparameter tuning
print('MAE:', metrics.mean_absolute_error(y_test, prediction))
print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
# Out:
# MAE: 20.616109405453432
# MSE: 1623.4047019429356
# RMSE: 40.2914966456067

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(regressor,X,Y,cv=5)

# %%
score.mean()
# Out:
# 0.744970110899368

# %%
from sklearn.metrics import r2_score

# %%
y_pred = xg_random.predict(X_test)

# %%
r2 = r2_score(y_test, y_pred)
print(f"R² Score: {r2}")
# Out:
# R² Score: 0.8109016919523627

# %% [markdown]
# ### Hyperparamter tuning with Grid Search CV

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'n_estimators': [500, 700, 900],
    'max_depth': [6, 7, 8],
    'learning_rate': [0.05, 0.07, 0.1],
    'subsample': [0.7, 0.8, 0.9],
    'colsample_bytree': [0.7, 0.8, 0.9]
}

# Initialize the model
xgb_model = xgb.XGBRegressor()

# Grid Search CV
grid_search_xgb = GridSearchCV(estimator=xgb_model, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)

# Fit the grid search model
grid_search_xgb.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'colsample_bytree': [0.7, 0.8, 0.9],
#                          'learning_rate': [0.05, 0.07, 0.1],
#                          'max_depth': [6, 7, 8],
#                          'n_estimators': [500, 700, 900],
#                          'subsample': [0.7, 0.8, 0.9]},
#              verbose=2)

# %%
grid_search_xgb.best_params_
# Out:
# {'colsample_bytree': 0.9,
#  'learning_rate': 0.07,
#  'max_depth': 7,
#  'n_estimators': 500,
#  'subsample': 0.8}

# %%
grid_search_xgb.best_score_
# Out:
# 0.76271611162995

# %%
y_pred = grid_search_xgb.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 r2_score(y_test, y_pred)
#
# NameError: name 'r2_score' is not defined

# %% [markdown]
# #### Evaluation of GridSearchCV

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np


mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
# Out:
# MAE: 18.138251779042562
# MSE: 1331.1399307561292
# RMSE: 36.48479040307247

# %% [markdown]
# ### Using GridSearchCV's best params to train the final model

# %%
import pandas as pd

# %%
data=pd.read_csv("AQI_data.csv")

# %%
data=data.dropna()

# %%
X=data.iloc[:,:-1] ## independent features
Y=data.iloc[:,-1]  ## dependent features

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
best_params={'colsample_bytree': 0.9,
 'learning_rate': 0.07,
 'max_depth': 7,
 'n_estimators': 500,
 'subsample': 0.8}

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# %%
xgb_best = XGBRegressor(**best_params, random_state=42)

# %%
xgb_best.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.9, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.07, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=500, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %% [markdown]
# #### Evaluation

# %%
y_pred = xgb_best.predict(X_test)

from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print(f'R^2: {r2}')
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print(f'Mean Absolute Error: {mae}')
print(f'Mean Squared Error: {mse}')
print(f'Root Mean Squared Error: {rmse}')
# Out:
# R^2: 0.8360996166839492
# Mean Absolute Error: 16.948350169621328
# Mean Squared Error: 986.8644965207172
# Root Mean Squared Error: 31.414399509153718

# %%
import joblib

# %%
joblib.dump(xgb_best, 'xgb_best_model.joblib')
# Out:
# ['xgb_best_model.joblib']
